# %%
from language.lexer import get_functions_atoms
from language.parser import parse,build_syntax_tree
from pathlib import Path
from language.structures import SourceCode, CodeRunner

# %%
text = Path("resources/array.js").read_text()
functions_atoms = get_functions_atoms(text)
functions_atoms
# Out:
# [[Atom(value='function', index=1, type='keyword'),
#   Atom(value='init', index=1, type='function_id'),
#   Atom(value='(', index=1, type='keyword'),
#   Atom(value=')', index=1, type='keyword'),
#   Atom(value='{', index=1, type='keyword'),
#   Atom(value='array_let', index=2, type='keyword'),
#   Atom(value='[', index=2, type='keyword'),
#   Atom(value=10, index=2, type='const'),
#   Atom(value=']', index=2, type='keyword'),
#   Atom(value='[', index=2, type='keyword'),
#   Atom(value=10, index=2, type='const'),
#   Atom(value=']', index=2, type='keyword'),
#   Atom(value='a', index=2, type='id'),
#   Atom(value=';', index=2, type='keyword'),
#   Atom(value='a', index=3, type='array_id'),
#   Atom(value='[', index=3, type='keyword'),
#   Atom(value=5, index=3, type='const'),
#   Atom(value=']', index=3, type='keyword'),
#   Atom(value='[', index=3, type='keyword'),
#   Atom(value=7, index=3, type='const'),
#   Atom(value=']', index=3, type='keyword'),
#   Atom(value='=', index=3, type='keyword'),
#   Atom(value=10, index=3, type='const'),
#   Atom(value=';', index=3, type='keyword'),
#   Atom(value='print', index=4, type='function_id'),
#   Atom(value='(', index=4, type='keyword'),
#   Atom(value='a', index=4, type='array_id'),
#   Atom(value='[', index=4, type='keyword'),
#   Atom(value=5, index=4, type='const'),
#   Atom(value=']', index=4, type='keyword'),
#   Atom(value='[', index=4, type='keyword'),
#   Atom(value=7, index=4, type='const'),
#   Atom(value=']', index=4, type='keyword'),
#   Atom(value=')', index=4, type='keyword'),
#   Atom(value=';', index=4, type='keyword'),
#   Atom(value='}', index=5, type='keyword')]]

# %%
parse(functions_atoms[0][:])
# Out:
# [Function -> ['function', Atom(value='init', index=1, type='function_id'), '(', 'Id_List', ')', '{', 'Instructions', '}'],
#  Id_List -> ['#'],
#  Instructions -> ['Instruction', 'Instructions'],
#  Instruction -> ['DefineArrayInstruction'],
#  DefineArrayInstruction -> ['array_let', 'ArrayIndexes', 'Id_List', ';'],
#  ArrayIndexes -> ['[', 'Expression', ']', 'ArrayIndexes'],
#  Expression -> ['T', 'E1'],
#  T -> ['F', 'T1'],
#  F -> [Atom(value=10, index=2, type='const')],
#  T1 -> ['#'],
#  E1 -> ['#'],
#  ArrayIndexes -> ['[', 'Expression', ']', 'ArrayIndexes'],
#  Expression -> ['T', 'E1'],
#  T -> ['F', 'T1'],
#  F -> [Atom(value=10, index=2, type='const')],
#  T1 -> ['#'],
#  E1 -> ['#'],
#  ArrayIndexes -> ['#'],
#  Id_List -> [Atom(value='a', index=2, type='id'), 'InitialValue', 'Id_List1'],
#  InitialValue -> ['#'],
#  Id_List1 -> ['#'],
#  Instructions -> ['Instruction', 'Instructions'],
#  Instruction -> ['AttributionInstruction'],
#  AttributionInstruction -> ['ArrayRef', '=', 'Expression', ';'],
#  ArrayRef -> [Atom(value='a', index=3, type='array_id'), 'ArrayIndexes'],
#  ArrayIndexes -> ['[', 'Expression', ']', 'ArrayIndexes'],
#  Expression -> ['T', 'E1'],
#  T -> ['F', 'T1'],
#  F -> [Atom(value=5, index=3, type='const')],
#  T1 -> ['#'],
#  E1 -> ['#'],
#  ArrayIndexes -> ['[', 'Expression', ']', 'ArrayIndexes'],
#  Expression -> ['T', 'E1'],
#  T -> ['F', 'T1'],
#  F -> [Atom(value=7, index=3, type='const')],
#  T1 -> ['#'],
#  E1 -> ['#'],
#  ArrayIndexes -> ['#'],
#  Expression -> ['T', 'E1'],
#  T -> ['F', 'T1'],
#  F -> [Atom(value=10, index=3, type='const')],
#  T1 -> ['#'],
#  E1 -> ['#'],
#  Instructions -> ['Instruction', 'Instructions'],
#  Instruction -> ['FunctionCallInstruction'],
#  FunctionCallInstruction -> ['FunctionCall', ';'],
#  FunctionCall -> [Atom(value='print', index=4, type='function_id'), '(', 'Parameters', ')'],
#  Parameters -> ['Expression', 'Parameters1'],
#  Expression -> ['T', 'E1'],
#  T -> ['F', 'T1'],
#  F -> ['ArrayValue'],
#  ArrayValue -> [Atom(value='a', index=4, type='array_id'), 'ArrayIndexes'],
#  ArrayIndexes -> ['[', 'Expression', ']', 'ArrayIndexes'],
#  Expression -> ['T', 'E1'],
#  T -> ['F', 'T1'],
#  F -> [Atom(value=5, index=4, type='const')],
#  T1 -> ['#'],
#  E1 -> ['#'],
#  ArrayIndexes -> ['[', 'Expression', ']', 'ArrayIndexes'],
#  Expression -> ['T', 'E1'],
#  T -> ['F', 'T1'],
#  F -> [Atom(value=7, index=4, type='const')],
#  T1 -> ['#'],
#  E1 -> ['#'],
#  ArrayIndexes -> ['#'],
#  T1 -> ['#'],
#  E1 -> ['#'],
#  Parameters1 -> ['#'],
#  Instructions -> ['#']]

# %%
root = build_syntax_tree(functions_atoms[0][:])
repr = root.build_dict()

# %%
import json
with open("nodes.json", 'w') as f:
    json.dump(repr, f)

# %%
source_code = SourceCode(text)
code_runner = CodeRunner(source_code)
code_runner.run("init")
# Out:
# [print 10]
