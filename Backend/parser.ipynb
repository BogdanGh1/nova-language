# %%
from language.lexer import identify_atoms,get_fip
from language.parser import get_rules, parse,build_syntax_tree
from pathlib import Path
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 2
#       1 from language.lexer import identify_atoms,get_fip
# ----> 2 from language.parser import get_rules, parse,build_syntax_tree
#       3 from pathlib import Path
#
# File c:\Users\Bogdan\Desktop\FMI Materiale\Licenta\Backend\language\parser.py:2
#       1 from language.utils import Atom, Production
# ----> 2 from language.nodes import Node, create_node
#       3 from language.lexer import get_fip
#       4 from pathlib import Path
#
# File c:\Users\Bogdan\Desktop\FMI Materiale\Licenta\Backend\language\nodes.py:2
#       1 from language.actions import Action
# ----> 2 from language.structures import Function
#       3 from language.variables import VariableTable
#       6 class Node:
#
# File c:\Users\Bogdan\Desktop\FMI Materiale\Licenta\Backend\language\structures.py:1
# ----> 1 from language.nodes import Node
#       2 from language.actions import Action
#       3 from language.variables import Variable, VariableScope, VariableTable
#
# ImportError: cannot import name 'Node' from partially initialized module 'language.nodes' (most likely due to a circular import) (c:\Users\Bogdan\Desktop\FMI Materiale\Licenta\Backend\language\nodes.py)

# %%
text = Path("resources/ex.js").read_text()
parse(text)
# Out:
# [Function -> ['function', Atom(value='init', index=1, type='id'), '(', 'Id_List', ')', '{', 'Instructions', '}'],
#  Id_List -> ['#'],
#  Instructions -> ['Instruction', 'Instructions'],
#  Instruction -> ['DefineGlobalInstruction'],
#  DefineGlobalInstruction -> ['global', 'let', 'Id_List', ';'],
#  Id_List -> [Atom(value='player', index=2, type='id'), 'Id_List1'],
#  Id_List1 -> ['#'],
#  Instructions -> ['Instruction', 'Instructions'],
#  Instruction -> ['DefineInstruction'],
#  DefineInstruction -> ['let', 'Id_List', ';'],
#  Id_List -> [Atom(value='c', index=3, type='id'), 'Id_List1'],
#  Id_List1 -> ['#'],
#  Instructions -> ['#']]

# %%
root = build_syntax_tree(text)
repr = root.build_dict()

# %%
import json
with open("nodes.json", 'w') as f:
    json.dump(repr, f)

# %%
root.eval()
# Out:
# Define global instruction
# Define instruction
