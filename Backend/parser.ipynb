# %%
from language.lexer import identify_atoms,get_fip, get_functions_atoms
from language.parser import get_rules, parse,build_syntax_tree
from pathlib import Path
from language.utils import Atom
from language.structures import SourceCode, CodeRunner, Function, PrintFunction

# %%
text = Path("resources/ex.js").read_text()
functions_atoms = get_functions_atoms(text)
parse(functions_atoms[0][:])
# Out:
# [Function -> ['function', Atom(value='init', index=1, type='function_id'), '(', 'Id_List', ')', '{', 'Instructions', '}'],
#  Id_List -> ['#'],
#  Instructions -> ['Instruction', 'Instructions'],
#  Instruction -> ['DefineInstruction'],
#  DefineInstruction -> ['let', 'Id_List', ';'],
#  Id_List -> [Atom(value='a', index=2, type='id'), 'Id_List1'],
#  Id_List1 -> [',', Atom(value='b', index=2, type='id'), 'Id_List1'],
#  Id_List1 -> ['#'],
#  Instructions -> ['Instruction', 'Instructions'],
#  Instruction -> ['AttributionInstruction'],
#  AttributionInstruction -> [Atom(value='a', index=3, type='id'), '=', 'Expression', ';'],
#  Expression -> ['T', 'E1'],
#  T -> ['F', 'T1'],
#  F -> [Atom(value=5, index=3, type='const')],
#  T1 -> ['#'],
#  E1 -> ['#'],
#  Instructions -> ['Instruction', 'Instructions'],
#  Instruction -> ['AttributionInstruction'],
#  AttributionInstruction -> [Atom(value='b', index=4, type='id'), '=', 'Expression', ';'],
#  Expression -> ['T', 'E1'],
#  T -> ['F', 'T1'],
#  F -> [Atom(value=5, index=4, type='const')],
#  T1 -> ['#'],
#  E1 -> ['+', 'T', 'E1'],
#  T -> ['F', 'T1'],
#  F -> [Atom(value='a', index=4, type='id')],
#  T1 -> ['#'],
#  E1 -> ['#'],
#  Instructions -> ['Instruction', 'Instructions'],
#  Instruction -> ['FunctionCall'],
#  FunctionCall -> [Atom(value='print', index=5, type='function_id'), '(', 'Parameters', ')', ';'],
#  Parameters -> ['Expression', 'Parameters1'],
#  Expression -> ['T', 'E1'],
#  T -> ['F', 'T1'],
#  F -> [Atom(value='a', index=5, type='id')],
#  T1 -> ['*', 'F', 'T1'],
#  F -> [Atom(value='b', index=5, type='id')],
#  T1 -> ['*', 'F', 'T1'],
#  F -> [Atom(value='b', index=5, type='id')],
#  T1 -> ['#'],
#  E1 -> ['+', 'T', 'E1'],
#  T -> ['F', 'T1'],
#  F -> [Atom(value=10, index=5, type='const')],
#  T1 -> ['#'],
#  E1 -> ['-', 'T', 'E1'],
#  T -> ['F', 'T1'],
#  F -> [Atom(value='a', index=5, type='id')],
#  T1 -> ['#'],
#  E1 -> ['#'],
#  Parameters1 -> ['#'],
#  Instructions -> ['Instruction', 'Instructions'],
#  Instruction -> ['FunctionCall'],
#  FunctionCall -> [Atom(value='init2', index=6, type='function_id'), '(', 'Parameters', ')', ';'],
#  Parameters -> ['#'],
#  Instructions -> ['#']]

# %%
root = build_syntax_tree(functions_atoms[0])
repr = root.build_dict()

# %%
import json
with open("nodes.json", 'w') as f:
    json.dump(repr, f)

# %%
source_code = SourceCode(text)
code_runner = CodeRunner(source_code)
code_runner.run("init")
# Out:
# [print 505, print 10]
