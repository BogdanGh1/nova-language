# %%
from language.lexer import identify_atoms, get_fip
from language.parser import get_rules, parse
from pathlib import Path

# %%
text = Path("resources/ex.js").read_text()
parse(text)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 2
#       1 text = Path("resources/ex.js").read_text()
# ----> 2 parse(text)
#
# File c:\Users\Bogdan\Desktop\FMI Materiale\Licenta\Backend\language\parser.py:179, in parse(text)
#     177 fip = get_fip(atoms)
#     178 fip_values = get_values_from_fip(fip)
# --> 179 return _parse(fip_values, parse_table, "Functions")
#
# File c:\Users\Bogdan\Desktop\FMI Materiale\Licenta\Backend\language\parser.py:162, in _parse(sequence, table, symbol)
#     160     return Node(symbol)
#     161 node = Node(symbol)
# --> 162 rule = table[symbol][sequence[-1]]
#     163 for x in rule:
#     164     child = _parse(sequence, table, x)
#
# KeyError: '}'
