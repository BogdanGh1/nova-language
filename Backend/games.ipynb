# %%
from api.domain.games.factory import create_game
from pathlib import Path

# %%
text = Path("resources/tic_tac_toe_example.js").read_text()
game = create_game("tictactoe","abc",text)
game

# %%
game.run_function("start")
# Out:
# [setScoreX 0, setScoreO 0]

# %%
game.run_function("clickCell",[1])
# Out:
# [setCell 1 X]

# %%
game.run_function("clickCell",[2])
# Out:
# [setCell 2 X]

# %%
game.run_function("clickCell",[0])
# Out:
# [setCell 0 X]

# %%
game.run_function("clickCell",[-1])
# Out:
# [setCell -1 X]
